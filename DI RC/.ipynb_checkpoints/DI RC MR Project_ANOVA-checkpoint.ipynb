# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
from statsmodels.formula.api import ols

# %%
data = pd.read_csv('C:\\Users\\User\\Desktop\\kmeans\\dataset_norm.csv')
data.head()
#############################################
radiofeature = data.loc[:, 'ADC(10-3mm2/s)':'Kpa']
label = data['Customlabel']
radiofeature.insert(0, "Customlabel", label, True)
radiofeature['Customlabel'] = radiofeature['Customlabel'].map({'Normal': 0, 'Fat': 1, 'Fibrosis': 2})
radiofeature.head()
# Out:
#    Customlabel  ADC(10-3mm2/s)  Dapp(10-3mm2/s)      Kapp     FF(%)  \
# 0            0        0.813388         0.586357  0.449992  0.137188
# 1            0        0.682775         0.470573  0.483713  0.147164
# 2            0        0.753347         0.511848  0.365092  0.137683
# 3            0        0.637752         0.416893  0.547105  0.047433
# 4            0        0.710831         0.668081  0.559145  0.015445
#
#    D*(10-3mm2/s)  D(10^-3)      f(%)       Kpa
# 0       0.888889  0.634109  0.740978  0.300000
# 1       0.644922  0.589743  0.496404  0.433333
# 2       0.513549  0.671412  0.311964  0.550000
# 3       0.707026  0.510620  0.411011  0.433333
# 4       0.908615  0.556002  0.634467  0.483333

# %%
d = radiofeature
d_melt = pd.melt(d, id_vars=['Customlabel'], value_vars=['ADC(10-3mm2/s)', 'Dapp(10-3mm2/s)', 'Kapp', 'D*(10-3mm2/s)', 'D(10^-3)', 'f(%)'])
# replace column names
d_melt.columns = ['Customlabel', 'parameter', 'value']
d_melt.head()
# Out:
#    Customlabel       parameter     value
# 0            0  ADC(10-3mm2/s)  0.813388
# 1            0  ADC(10-3mm2/s)  0.682775
# 2            0  ADC(10-3mm2/s)  0.753347
# 3            0  ADC(10-3mm2/s)  0.637752
# 4            0  ADC(10-3mm2/s)  0.710831

# %% [markdown]
# # generate a boxplot to see the data distribution by genotypes and years. Using boxplot, we can easily detect the
# # differences between different groups

# %%
sns.boxplot(x="Customlabel", y="value", hue="parameter", data=d_melt, palette="Set1")
# Out:
# <AxesSubplot:xlabel='Customlabel', ylabel='value'>

# %%
df = radiofeature
df
# Out:
#     Customlabel  ADC(10-3mm2/s)  Dapp(10-3mm2/s)      Kapp     FF(%)  \
# 0             0        0.813388         0.586357  0.449992  0.137188
# 1             0        0.682775         0.470573  0.483713  0.147164
# 2             0        0.753347         0.511848  0.365092  0.137683
# 3             0        0.637752         0.416893  0.547105  0.047433
# 4             0        0.710831         0.668081  0.559145  0.015445
# ..          ...             ...              ...       ...       ...
# 65            2        0.764994         0.603797  0.446304  0.065846
# 66            2        0.528730         0.572685  0.658887  0.043448
# 67            2        0.672644         0.596989  0.508386  0.029680
# 68            2        0.670263         0.572685  0.609517  0.010223
# 69            2        0.650840         0.604883  0.576730  0.021078
#
#     D*(10-3mm2/s)  D(10^-3)      f(%)       Kpa
# 0        0.888889  0.634109  0.740978  0.300000
# 1        0.644922  0.589743  0.496404  0.433333
# 2        0.513549  0.671412  0.311964  0.550000
# 3        0.707026  0.510620  0.411011  0.433333
# 4        0.908615  0.556002  0.634467  0.483333
# ..            ...       ...       ...       ...
# 65       0.681987  0.681766  0.411073  0.600000
# 66       0.207973  0.446507  0.375110  1.000000
# 67       0.279219  0.615785  0.201146  0.633333
# 68       0.389589  0.558996  0.430519  0.783333
# 69       0.202619  0.600726  0.455610  0.850000
#
# [70 rows x 9 columns]

# %% [markdown]
# # create function for summary data
# # Create function to display distribution pairplot

# %%
def overview(df):
    #docstring
    '''
    Read a csv file into a DataFrame.
    Print first 5 rows of data.
    Print datatype for each column.
    Print number of NULL/NaN values for each column.
    Print summary data.
    
    Return:
    data, rtype: DataFrame
    '''
    print("The first 5 rows of data are:\n", df.head())
    print("\n")
    print("The (Row,Column) is:\n", df.shape)
    print("\n")
    print("Data type of each column:\n", df.dtypes)
    print("\n")
    print("The number of null values in each column are:\n", df.isnull().sum())
    print("\n")
    print("Summary of data:\n", df.describe())
    return


def distribution(dataset, variable):
    '''
    Args:
        dataset: Include the DataFrame here
        variable: Include the column from dataframe used for color encoding
    Returns:
        sns pairplot with color encoding
    '''
    
    g = sns.pairplot(data = dataset, hue = variable, size = 2)
    g.fig.suptitle('Graph showing distribution between scores and {}'.format(variable), fontsize=7)
    g.fig.subplots_adjust(top=0.9)
   
    return g

# %%
overview(df)
# Out:
# The first 5 rows of data are:
#     Customlabel  ADC(10-3mm2/s)  Dapp(10-3mm2/s)      Kapp     FF(%)  \
# 0            0        0.813388         0.586357  0.449992  0.137188
# 1            0        0.682775         0.470573  0.483713  0.147164
# 2            0        0.753347         0.511848  0.365092  0.137683
# 3            0        0.637752         0.416893  0.547105  0.047433
# 4            0        0.710831         0.668081  0.559145  0.015445
#
#    D*(10-3mm2/s)  D(10^-3)      f(%)       Kpa
# 0       0.888889  0.634109  0.740978  0.300000
# 1       0.644922  0.589743  0.496404  0.433333
# 2       0.513549  0.671412  0.311964  0.550000
# 3       0.707026  0.510620  0.411011  0.433333
# 4       0.908615  0.556002  0.634467  0.483333
#
#
# The (Row,Column) is:
#  (70, 9)
#
#
# Data type of each column:
#  Customlabel          int64
# ADC(10-3mm2/s)     float64
# Dapp(10-3mm2/s)    float64
# Kapp               float64
# FF(%)              float64
# D*(10-3mm2/s)      float64
# D(10^-3)           float64
# f(%)               float64
# Kpa                float64
# dtype: object
#
#
# The number of null values in each column are:
#  Customlabel        0
# ADC(10-3mm2/s)     0
# Dapp(10-3mm2/s)    0
# Kapp               0
# FF(%)              0
# D*(10-3mm2/s)      0
# D(10^-3)           0
# f(%)               0
# Kpa                0
# dtype: int64
#
#
# Summary of data:
#         Customlabel  ADC(10-3mm2/s)  Dapp(10-3mm2/s)       Kapp      FF(%)  \
# count    70.000000       70.000000        70.000000  70.000000  70.000000
# mean      0.914286        0.630733         0.544821   0.591023   0.211249
# std       0.793869        0.113022         0.114667   0.160550   0.236352
# min       0.000000        0.379396         0.380143   0.203780   0.004173
# 25%       0.000000        0.551303         0.460546   0.488148   0.044822
# 50%       1.000000        0.637796         0.540566   0.551880   0.087914
# 75%       2.000000        0.709451         0.603366   0.689421   0.380043
# max       2.000000        1.000000         1.000000   1.000000   1.000000
#
#        D*(10-3mm2/s)   D(10^-3)       f(%)        Kpa
# count      70.000000  70.000000  70.000000  70.000000
# mean        0.533438   0.506670   0.545941   0.479048
# std         0.242838   0.122562   0.200778   0.176239
# min         0.007790   0.243084   0.008412   0.250000
# 25%         0.343155   0.428145   0.390028   0.333333
# 50%         0.551643   0.525162   0.560971   0.425000
# 75%         0.701003   0.585358   0.686739   0.625000
# max         1.000000   1.000000   1.000000   1.000000

# %%
df.columns
# Out:
# Index(['Customlabel', 'ADC', 'Dapp', 'Kapp', 'FF', 'Dstar', 'D', 'f', 'Kpa'], dtype='object')

# %%
df.columns = ['Customlabel', 'ADC', 'Dapp', 'Kapp', 'FF',
       'Dstar', 'D', 'f', 'Kpa']

# %%
db = df.loc[:, ['Customlabel', 'ADC', 'Dapp', 'Kapp',
       'Dstar', 'D', 'f']]
db
# Out:
#     Customlabel       ADC      Dapp      Kapp     Dstar         D         f
# 0             0  0.813388  0.586357  0.449992  0.888889  0.634109  0.740978
# 1             0  0.682775  0.470573  0.483713  0.644922  0.589743  0.496404
# 2             0  0.753347  0.511848  0.365092  0.513549  0.671412  0.311964
# 3             0  0.637752  0.416893  0.547105  0.707026  0.510620  0.411011
# 4             0  0.710831  0.668081  0.559145  0.908615  0.556002  0.634467
# ..          ...       ...       ...       ...       ...       ...       ...
# 65            2  0.764994  0.603797  0.446304  0.681987  0.681766  0.411073
# 66            2  0.528730  0.572685  0.658887  0.207973  0.446507  0.375110
# 67            2  0.672644  0.596989  0.508386  0.279219  0.615785  0.201146
# 68            2  0.670263  0.572685  0.609517  0.389589  0.558996  0.430519
# 69            2  0.650840  0.604883  0.576730  0.202619  0.600726  0.455610
#
# [70 rows x 7 columns]

# %%
distribution(db, 'Customlabel')
# Out:
# C:\Users\User\anaconda3\envs\ganzer\lib\site-packages\seaborn\axisgrid.py:1912: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# # Create anova test function

# %%
def anova_test(data, variable):
    '''
    Args: 
        data = (DataFrame)
        variable = Categorical column used for 1-way ANOVA test
    Returns: Nothing
    '''
    x = ['Customlabel', 'ADC', 'Dapp', 'Kapp', 'Dstar', 'D', 'f']
    for i,k in enumerate(x):
        lm = ols('{} ~ {}'.format(x[i],variable), data=data).fit()
        table = sm.stats.anova_lm(lm)
        print(':::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::')
        print("P-value for 1-way ANOVA test between {} and {} is ".format(x[i],variable),table.loc[variable,'PR(>F)'])
        print(lm.summary())   
        print(':::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::')

# %%
anova_test(db, 'Customlabel')
# Out:
# :::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::
# P-value for 1-way ANOVA test between Customlabel and Customlabel is  0.0
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            Customlabel   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                  1.000
# Method:                 Least Squares   F-statistic:                 3.903e+32
# Date:                Mon, 07 Jun 2021   Prob (F-statistic):               0.00
# Time:                        15:43:40   Log-Likelihood:                 2396.2
# No. Observations:                  70   AIC:                            -4788.
# Df Residuals:                      68   BIC:                            -4784.
# Df Model:                           1
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept   -3.192e-16   6.11e-17     -5.224      0.000   -4.41e-16   -1.97e-16
# Customlabel     1.0000   5.06e-17   1.98e+16      0.000       1.000       1.000
# ==============================================================================
# Omnibus:                      151.490   Durbin-Watson:                   0.045
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):                8.694
# Skew:                           0.355   Prob(JB):                       0.0129
# Kurtosis:                       1.426   Cond. No.                         2.75
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# :::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::
# :::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::
# P-value for 1-way ANOVA test between ADC and Customlabel is  9.379559824919779e-05
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    ADC   R-squared:                       0.202
# Model:                            OLS   Adj. R-squared:                  0.191
# Method:                 Least Squares   F-statistic:                     17.24
# Date:                Mon, 07 Jun 2021   Prob (F-statistic):           9.38e-05
# Time:                        15:43:40   Log-Likelihood:                 61.700
# No. Observations:                  70   AIC:                            -119.4
# Df Residuals:                      68   BIC:                            -114.9
# Df Model:                           1
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept       0.6893      0.019     37.030      0.000       0.652       0.726
# Customlabel    -0.0640      0.015     -4.153      0.000      -0.095      -0.033
# ==============================================================================
# Omnibus:                        2.375   Durbin-Watson:                   1.878
# Prob(Omnibus):                  0.305   Jarque-Bera (JB):                1.615
# Skew:                           0.263   Prob(JB):                        0.446
# Kurtosis:                       3.525   Cond. No.                         2.75
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# :::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::
# :::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::
# P-value for 1-way ANOVA test between Dapp and Customlabel is  0.7406670478087126
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   Dapp   R-squared:                       0.002
# Model:                            OLS   Adj. R-squared:                 -0.013
# Method:                 Least Squares   F-statistic:                    0.1104
# Date:                Mon, 07 Jun 2021   Prob (F-statistic):              0.741
# Time:                        15:43:40   Log-Likelihood:                 52.835
# No. Observations:                  70   AIC:                            -101.7
# Df Residuals:                      68   BIC:                            -97.17
# Df Model:                           1
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept       0.5395      0.021     25.536      0.000       0.497       0.582
# Customlabel     0.0058      0.018      0.332      0.741      -0.029       0.041
# ==============================================================================
# Omnibus:                       30.504   Durbin-Watson:                   2.057
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               63.347
# Skew:                           1.485   Prob(JB):                     1.76e-14
# Kurtosis:                       6.591   Cond. No.                         2.75
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# :::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::
# :::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::
# P-value for 1-way ANOVA test between Kapp and Customlabel is  0.11060051173616849
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   Kapp   R-squared:                       0.037
# Model:                            OLS   Adj. R-squared:                  0.023
# Method:                 Least Squares   F-statistic:                     2.613
# Date:                Mon, 07 Jun 2021   Prob (F-statistic):              0.111
# Time:                        15:43:40   Log-Likelihood:                 30.538
# No. Observations:                  70   AIC:                            -57.08
# Df Residuals:                      68   BIC:                            -52.58
# Df Model:                           1
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept       0.5555      0.029     19.120      0.000       0.497       0.613
# Customlabel     0.0389      0.024      1.617      0.111      -0.009       0.087
# ==============================================================================
# Omnibus:                        2.253   Durbin-Watson:                   1.608
# Prob(Omnibus):                  0.324   Jarque-Bera (JB):                1.513
# Skew:                           0.234   Prob(JB):                        0.469
# Kurtosis:                       3.547   Cond. No.                         2.75
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# :::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::
# :::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::
# P-value for 1-way ANOVA test between Dstar and Customlabel is  0.0034258064275668226
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Dstar   R-squared:                       0.119
# Model:                            OLS   Adj. R-squared:                  0.106
# Method:                 Least Squares   F-statistic:                     9.199
# Date:                Mon, 07 Jun 2021   Prob (F-statistic):            0.00343
# Time:                        15:43:40   Log-Likelihood:                 4.6940
# No. Observations:                  70   AIC:                            -5.388
# Df Residuals:                      68   BIC:                           -0.8910
# Df Model:                           1
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept       0.6300      0.042     14.990      0.000       0.546       0.714
# Customlabel    -0.1056      0.035     -3.033      0.003      -0.175      -0.036
# ==============================================================================
# Omnibus:                        1.831   Durbin-Watson:                   2.325
# Prob(Omnibus):                  0.400   Jarque-Bera (JB):                1.325
# Skew:                          -0.083   Prob(JB):                        0.516
# Kurtosis:                       2.347   Cond. No.                         2.75
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# :::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::
# :::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::
# P-value for 1-way ANOVA test between D and Customlabel is  0.4595244771700724
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      D   R-squared:                       0.008
# Model:                            OLS   Adj. R-squared:                 -0.007
# Method:                 Least Squares   F-statistic:                    0.5533
# Date:                Mon, 07 Jun 2021   Prob (F-statistic):              0.460
# Time:                        15:43:40   Log-Likelihood:                 48.401
# No. Observations:                  70   AIC:                            -92.80
# Df Residuals:                      68   BIC:                            -88.31
# Df Model:                           1
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept       0.5194      0.023     23.074      0.000       0.474       0.564
# Customlabel    -0.0139      0.019     -0.744      0.460      -0.051       0.023
# ==============================================================================
# Omnibus:                       15.512   Durbin-Watson:                   1.849
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               29.311
# Skew:                           0.720   Prob(JB):                     4.32e-07
# Kurtosis:                       5.824   Cond. No.                         2.75
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# :::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::
# :::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::
# P-value for 1-way ANOVA test between f and Customlabel is  0.16972101994147248
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      f   R-squared:                       0.028
# Model:                            OLS   Adj. R-squared:                  0.013
# Method:                 Least Squares   F-statistic:                     1.926
# Date:                Mon, 07 Jun 2021   Prob (F-statistic):              0.170
# Time:                        15:43:40   Log-Likelihood:                 14.544
# No. Observations:                  70   AIC:                            -25.09
# Df Residuals:                      68   BIC:                            -20.59
# Df Model:                           1
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept       0.5843      0.037     16.005      0.000       0.511       0.657
# Customlabel    -0.0420      0.030     -1.388      0.170      -0.102       0.018
# ==============================================================================
# Omnibus:                        0.779   Durbin-Watson:                   2.072
# Prob(Omnibus):                  0.677   Jarque-Bera (JB):                0.886
# Skew:                          -0.177   Prob(JB):                        0.642
# Kurtosis:                       2.577   Cond. No.                         2.75
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# :::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::
